# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/ELCOT/Desktop/abc/housetrain.csv")         ##reading dataset

# %%
pd.set_option("display.max_columns",100)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
pd.set_option("display.max_rows",100)

# %%
df.isna().sum() ##cheching no of null values in our dataset
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
#### feture which may has nan values 
featurenan=[feat for feat in df.columns if df[feat].isna().sum()>1]

# %%
featurenan
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for feat in featurenan:
    print("{}....missing value...{}".format(feat,np.round(df[feat].isna().mean(),4)))
# Out:
# LotFrontage....missing value...0.1774
# Alley....missing value...0.9377
# MasVnrType....missing value...0.0055
# MasVnrArea....missing value...0.0055
# BsmtQual....missing value...0.0253
# BsmtCond....missing value...0.0253
# BsmtExposure....missing value...0.026
# BsmtFinType1....missing value...0.0253
# BsmtFinType2....missing value...0.026
# FireplaceQu....missing value...0.4726
# GarageType....missing value...0.0555
# GarageYrBlt....missing value...0.0555
# GarageFinish....missing value...0.0555
# GarageQual....missing value...0.0555
# GarageCond....missing value...0.0555
# PoolQC....missing value...0.9952
# Fence....missing value...0.8075
# MiscFeature....missing value...0.963

# %%
df.shape
# Out:
# (1460, 81)

# %%
len(featurenan)   #### we have 18 features which may has nan values in those
# Out:
# 18

# %%
##3finding relation ship between features which may has nan values and target variable
for feat in featurenan:
    data=df.copy()
    data[feat]=np.where(df[feat].isna(),1,0)
    data.groupby(feat)["SalePrice"].mean().plot(kind="bar")
    plt.title(feat)
    plt.show()

# %% [markdown]
# # the above graphs tells that missing values plays a huge important in saleprice why because those has high saleprice

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
numfeatures=[feat for feat in df.columns if df[feat].dtype!="object"]

# %%
len(numfeatures)      ###we have 38 numerical features in our data set
# Out:
# 38

# %%
df[numfeatures]
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %%
yearfeatures=[feat for feat in numfeatures if  "Yr" in feat or "Year" in feat]

# %%
yearfeatures
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
df.groupby("YrSold")["SalePrice"].median().plot()
# Out:
# <AxesSubplot:xlabel='YrSold'>

# %%
discretefeatures=[feat for feat in numfeatures if df[feat].nunique()<25 and feat not in yearfeatures+["Id"]]

# %%
discretefeatures
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
####3 relation ship with target  to discrete vaariables
for feat in discretefeatures:
    data=df.copy()
    data.groupby(feat)["SalePrice"].mean().plot(kind="bar")
    plt.title(feat)
    plt.show()

# %%
continuousfeatures=[feat for feat in numfeatures if feat not in discretefeatures+yearfeatures+["Id"]]

# %%
len(continuousfeatures)
# Out:
# 16

# %%
##3 handling missing values
for feat in numfeatures:
    
    df[feat]=df[feat].fillna(df[feat].mean())

# %%
for feat in continuousfeatures:
    data=df.copy()
    data[feat].hist(bins=25)
    plt.show()

# %%
df[numfeatures].isna().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
categoricalfeatures=[feat for feat in df.columns if df[feat].dtypes=="object"]

# %%
def replacingnancat(df,cat):
    
    data=df.copy()
    data[cat]=data[cat].fillna("missing")
    return data

# %%
df=replacingnancat(df,categoricalfeatures)

# %%
df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# ...

# %% [markdown]
# # from above step we replace all nan values

# %%
 for feat in continuousfeatures:
        if 0 in data[feat].unique():
            pass
        else:
            df[feat]=np.log(df[feat])

# %%
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley  \
# 0        1          60       RL     4.174387  9.041922   Pave  missing
# 1        2          20       RL     4.382027  9.169518   Pave  missing
# 2        3          60       RL     4.219508  9.328123   Pave  missing
# 3        4          70       RL     4.094345  9.164296   Pave  missing
# 4        5          60       RL     4.430817  9.565214   Pave  missing
# ...    ...         ...      ...          ...       ...    ...      ...
# 1455  1456          60       RL     4.127134  8.976768   Pave  missing
# 1456  1457          20       RL     4.442651  9.486076   Pave  missing
# 1457  1458          70       RL     4.189655  9.109636   Pave  missing
# 1458  1459          20       RL     4.219508  9.181632   Pave  missing
# 1459  1460          20       RL     4.317488  9.204020   Pave  missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
import pylab

# %%
import scipy.stats

# %%
for feat in continuousfeatures:
    data=df.copy()
    plt.figure(figsize=(12,10))
    plt.subplot(1,2,1)
    data[feat].hist(bins=25)
    plt.subplot(1,2,2)
    scipy.stats.probplot(data[feat],plot=pylab)
    plt.title(feat)
    plt.show()

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley  \
# 0        1          60       RL     4.174387  9.041922   Pave  missing
# 1        2          20       RL     4.382027  9.169518   Pave  missing
# 2        3          60       RL     4.219508  9.328123   Pave  missing
# 3        4          70       RL     4.094345  9.164296   Pave  missing
# 4        5          60       RL     4.430817  9.565214   Pave  missing
# ...    ...         ...      ...          ...       ...    ...      ...
# 1455  1456          60       RL     4.127134  8.976768   Pave  missing
# 1456  1457          20       RL     4.442651  9.486076   Pave  missing
# 1457  1458          70       RL     4.189655  9.109636   Pave  missing
# 1458  1459          20       RL     4.219508  9.181632   Pave  missing
# 1459  1460          20       RL     4.317488  9.204020   Pave  missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %% [markdown]
# # feature scaling

# %%
featurescale=[feat for feat in df.columns if feat not in ["Id","SalePrice"]]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for feat in categoricalfeatures:
    df[feat]=le.fit_transform(df[feat])                    ####sscaling of categorical variables

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0        1          60         3     4.174387  9.041922       1      2
# 1        2          20         3     4.382027  9.169518       1      2
# 2        3          60         3     4.219508  9.328123       1      2
# 3        4          70         3     4.094345  9.164296       1      2
# 4        5          60         3     4.430817  9.565214       1      2
# ...    ...         ...       ...          ...       ...     ...    ...
# 1455  1456          60         3     4.127134  8.976768       1      2
# 1456  1457          20         3     4.442651  9.486076       1      2
# 1457  1458          70         3     4.189655  9.109636       1      2
# 1458  1459          20         3     4.219508  9.181632       1      2
# 1459  1460          20         3     4.317488  9.204020       1      2
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
#### scaling of numeric variables
from sklearn.preprocessing import MinMaxScaler

# %%
min=MinMaxScaler()

# %%
for feat in featurescale:
    df[feat]=min.fit_transform(df[[feat]])

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0        1    0.235294      0.75     0.418208  0.366344     1.0    1.0
# 1        2    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2        3    0.235294      0.75     0.434909  0.422359     1.0    1.0
# 3        4    0.294118      0.75     0.388581  0.390295     1.0    1.0
# 4        5    0.235294      0.75     0.513123  0.468761     1.0    1.0
# ...    ...         ...       ...          ...       ...     ...    ...
# 1455  1456    0.235294      0.75     0.400718  0.353592     1.0    1.0
# 1456  1457    0.000000      0.75     0.517503  0.453273     1.0    1.0
# 1457  1458    0.294118      0.75     0.423859  0.379597     1.0    1.0
# 1458  1459    0.000000      0.75     0.434909  0.393688     1.0    1.0
# 1459  1460    0.000000      0.75     0.471175  0.398069     1.0    1.0
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %% [markdown]
# # the above data is ready to modek
